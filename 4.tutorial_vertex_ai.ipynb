# %%
from google import genai
from PIL import Image

# %%
# 1. Initialize the client (automatically picks up GEMINI_API_KEY from environment)
client = genai.Client(
    vertexai=True,
    project="infinitas-ds-ai-poc",
    location="us-central1",
)

# %%
# 2. Open your local image file
image_path = "test_image.jpg"
img = Image.open(image_path)

# %%
# 3. Generate content by passing both the image object and your text prompt
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        "Describe what you see in this image in detail, and list three main colors.",
        img
    ]
)

# %%
# 4. Print the text result
print(response.text)
# Out:
# This image presents a stunning, detailed view of the Sun, appearing as a massive, intensely glowing sphere set against the stark blackness of space.
#
# **Detailed Description:**
#
# The dominant feature is the Sun, occupying the majority of the frame. Its shape is perfectly spherical, and its surface is far from uniform, displaying a dynamic and highly textured appearance. The overall impression is one of immense heat and energy.
#
# *   **Surface Activity:** The Sun's disk is characterized by a mottled, granular texture, indicative of constant convection and plasma movement. Scattered across its surface are numerous bright, almost white-hot patches. These are likely active regions, such as solar flares or areas of intense magnetic activity, which stand out vibrantly against the slightly deeper orange of the surrounding surface. Some of these bright areas appear to have complex, interwoven patterns.
# *   **Color Gradation:** The main body of the Sun transitions from a brilliant, intense orange and yellow-orange in its brighter spots to a deeper, richer orange in less active areas. This gradation creates a sense of depth and three-dimensionality.
# *   **Limb and Aura:** Around the fiery orange disk, there's a distinct, glowing red halo or corona, which seems to extend outwards slightly into the darkness. In various places along the limb (edge) of the Sun, particularly visible in the crops, there appear to be small, flame-like or spiky protrusions extending from the surface into this reddish glow, likely solar prominences or spicules.
# *   **Background:** The background is an absolute, uniform black, which serves to dramatically emphasize the Sun's brilliance and isolated grandeur in space.
#
# **Three Main Colors:**
#
# 1.  **Orange:** This is the predominant color of the Sun's main body, ranging from bright, intense orange-yellow to a deeper, fiery orange.
# 2.  **Red:** Visible in the halo or aura surrounding the Sun, and also as a deeper, more intense hue within some of the Sun's surface features.
# 3.  **Black:** The color of the vast, empty space surrounding the Sun.

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       avg_logprobs=-1.4672888043283046,
#       content=Content(
#         parts=[
#           Part(
#             text="""This image presents a stunning, detailed view of the Sun, appearing as a massive, intensely glowing sphere set against the stark blackness of space.
#
# **Detailed Description:**
#
# The dominant feature is the Sun, occupying the majority of the frame. Its shape is perfectly spherical, and its surface is far from uniform, displaying a dynamic and highly textured appearance. The overall impression is one of immense heat and energy.
#
# *   **Surface Activity:** The Sun's disk is characterized by a mottled, granular texture, indicative of constant convection and plasma movement. Scattered across its surface are numerous bright, almost white-hot patches. These are likely active regions, such as solar flares or areas of intense magnetic activity, which stand out vibrantly against the slightly deeper orange of the surrounding surface. Some of these bright areas appear to have complex, interwoven patterns.
# *   **Color Gradation:** The main body of the Sun transitions from a brilliant, intense orange and yellow-orange in its brighter spots to a deeper, richer orange in less active areas. This gradation creates a sense of depth and three-dimensionality.
# *   **Limb and Aura:** Around the fiery orange disk, there's a distinct, glowing red halo or corona, which seems to extend outwards slightly into the darkness. In various places along the limb (edge) of the Sun, particularly visible in the crops, there appear to be small, flame-like or spiky protrusions extending from the surface into this reddish glow, likely solar prominences or spicules.
# *   **Background:** The background is an absolute, uniform black, which serves to dramatically emphasize the Sun's brilliance and isolated grandeur in space.
#
# **Three Main Colors:**
#
# 1.  **Orange:** This is the predominant color of the Sun's main body, ranging from bright, intense orange-yellow to a deeper, fiery orange.
# 2.  **Red:** Visible in the halo or aura surrounding the Sun, and also as a deeper, more intense hue within some of the Sun's surface features.
# 3.  **Black:** The color of the vast, empty space surrounding the Sun."""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>
#     ),
#   ],
#   create_time=datetime.datetime(2026, 6, 10, 2, 13, 15, 936372, tzinfo=TzInfo(0)),
#   model_version='gemini-2.5-flash',
#   response_id='O8goarSTOZi388AP3cXXgQE',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=10>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=435,
#     candidates_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=435
#       ),
#     ],
#     prompt_token_count=1822,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.IMAGE: 'IMAGE'>,
#         token_count=1806
#       ),
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=16
#       ),
#     ],
#     thoughts_token_count=1006,
#     total_token_count=3263,
#     traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
#   )
# )
